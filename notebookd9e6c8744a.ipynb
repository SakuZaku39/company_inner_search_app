# %% [markdown]
# <a href="https://colab.research.google.com/github/SakuZaku39/company_inner_search_app/blob/main/notebookd9e6c8744a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
wenjiechen0423_titanic_path = kagglehub.dataset_download('wenjiechen0423/titanic')

print('Data source import complete.')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# CSVファイルの読み込み
df = pd.read_csv('train.csv')

# trainデータを出力
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_55/2416040298.py in <cell line: 0>()
#       2
#       3 # CSVファイルの読み込み
# ----> 4 df = pd.read_csv('train.csv')
#       5
#       6 # trainデータを出力
#
# ...
